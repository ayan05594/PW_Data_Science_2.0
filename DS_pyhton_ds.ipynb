# %%
# Q1. How do you comment code in Python? What are the different types of comments?
# In Python, comments are used to explain code or make notes in the code. There are two types of comments:

# 1. Single-line comments: These are used for brief explanations or notes.
# Syntax: # followed by the comment
# Example:
# This is a single-line comment.

# 2. Multi-line comments: These are used when comments span multiple lines. 
# Syntax: triple quotes ''' or """ can be used for multi-line comments.
# Example:
'''
This is a 
multi-line comment.
'''

# Q2. What are variables in Python? How do you declare and assign values to variables?
# A variable in Python is a name that refers to a value. You can declare a variable and assign a value to it in one step.

# Example:
age = 25  # Declaring a variable named 'age' and assigning the value 25 to it.

# Q3. How do you convert one data type to another in Python?
# In Python, you can convert data types using type casting functions like int(), float(), str(), etc.

# Example:
x = "10"  # String
x = int(x)  # Converting string to integer

y = 3.14  # Float
y = int(y)  # Converting float to integer

# Q4. How do you write and execute a Python script from the command line?
# 1. Write a Python script in a text editor and save it with a .py extension (e.g., script.py).
# 2. Open the command line (Terminal or Command Prompt).
# 3. Navigate to the folder containing the script using the 'cd' command.
# 4. Type 'python script.py' or 'python3 script.py' (depending on your Python installation) to execute the script.

# Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].
my_list = [1, 2, 3, 4, 5]
sub_list = my_list[1:3]  # Slicing the list to get the sub-list [2, 3]
print(sub_list)

# Q6. What is a complex number in mathematics, and how is it represented in Python?
# A complex number in mathematics is a number of the form a + bi, where 'a' is the real part and 'b' is the imaginary part.
# In Python, complex numbers are represented with a real and imaginary part.

# Example:
z = 3 + 4j  # A complex number, where 3 is the real part and 4 is the imaginary part
print(z)

# Q7. What is the correct way to declare a variable named age and assign the value 25 to it?
age = 25  # Declaring the variable 'age' and assigning the value 25

# Q8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable belong to?
price = 9.99  # The variable 'price' is assigned a floating-point value.
print(type(price))  # Output will be <class 'float'>

# Q9. Create a variable named name and assign your full name to it as a string. How would you print the value of this variable?
name = "John Doe"  # Assigning a string value to the variable 'name'
print(name)  # Printing the value of the 'name' variable

# Q10. Given the string "Hello, World!", extract the substring "World".
str = "Hello, World!"
substring = str[7:12]  # Extracting the substring "World"
print(substring)

# Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are currently a student or not.
is_student = True  # Boolean variable indicating that I am a student
print(is_student)
# Out:
# Error: Something went wrong
# BaseException
#     BaseExceptionGroup
#         ExceptionGroup
#     Exception
#         ArithmeticError
#             FloatingPointError
#             OverflowError
#             ZeroDivisionError
#                 DivisionByZero
#                 DivisionUndefined
#             DecimalException
#                 Clamped
#                 Rounded
#                     Underflow
#                     Overflow
#                 Inexact
#                     Underflow
#                     Overflow
#                 Subnormal
#                     Underflow
#                 DivisionByZero
#                 FloatOperation
#                 InvalidOperation
#                     ConversionSyntax
#                     DivisionImpossible
#                     DivisionUndefined
#                     InvalidContext
#         AssertionError
#         AttributeError
#             FrozenInstanceError
#             OptionError
#         BufferError
# ...
